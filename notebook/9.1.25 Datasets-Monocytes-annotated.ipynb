# %% [markdown]
# # Blood Monocytes:
#
#
# ## GSE49753
#
# monocyte-derived dendritic cells. Ex-vivo experiments.
# Medium alone (control).
# Plasma from sepsis patients.
# Plasma from uninfected controls.
# Lipopolysaccharide (LPS) as a positive control for immune activation.
#
# Present genes :42
#
# Missing genes:12("CALCA" "CRP"   "LBP"   "IFNG"  "IFNA1" "IFNA2" "IFNB1" "CCL25" "MMP8"  "ARG1"  "CD177" "OLFM4" "GATA3")
#
#
# ## GSE65517
#
# Comparative analysis of monocytes from healthy donors, patients with metastatic breast cancer, sepsis or tuberculosis.
#
# Sepsis G- + breast cancer + tuberculosis + healthy control.
#
# Present genes :54
#
# Missing genes:0
#
#
# ## GSE136200
#
# RNA-Seq data of purified CD14+ monocytes, CD4+, CD8+ T cells and CD19+ B cells from six critically ill patients with sepsis due to community-acquired pneumonia and four healthy subjects.
#
# Sepsis + healthy.
#
# **CD4** : Present genes :46
#
# Missing genes:8("CRP"    "LBP"    "IL6"    "CXCL10" "IFNA1"  "IFNA2"  "CCL19"  "CCL25"  "CCL2")
#
#
# **CD14* : Present genes :45
#
# Missing genes:9 ("CALCA" "CRP"   "IL6"   "IFNA1" "IFNA2" "IFNB1" "CCL19" "CCL25" "PDCD1" "VCAM1")
#
#
# **CD8** : Present genes :46
#
# Missing genes: 8("CRP"    "LBP"    "IL6"    "CXCL10" "IFNA1"  "IFNA2"  "CCL19"  "CCL25"  "CCL2")
#
#
# **CD19** : Present genes :41
#
# Missing genes:13("CALCA"  "CRP"    "LBP"    "ELANE"  "IL10"   "CXCL10" "IFNA1"  "IFNA2"  "IFNB1"  "CCL19"  "CCL25"  "PDCD1"  "CCL2"  "VCAM1")
#
#
# ## GSE139913
# Analysis of the RNA expression of circulating CD14+ monocytes of healthy volunteers and intensive care unit (ICU) patients with and without sepsis.Differential gene expression in circulating CD14+ monocytes indicates the prognosis of critically ill patients with sepsis.
#
# Sepsis + non sepsis + healthy.
#
#
# Present genes :50
#
# Missing genes:4("CALCA" "IFNG"  "IFNA1" "IFNA2" "IFNB1")
#
#
# ## GSE133822
#
# mRNA profiles of CD4, CD8 and CD14 cells were generated for sepsis, critically-ill non-septic, cancer patients and age-matched healthy controls using Illumina Hiseq 2500.T cell and Monocyte Specific RNAseq Analysis in Septic and Non Septic Critically-Ill Patients and in Patients with Cancer.
# Sepsis + non sepsis + cancer + healthy.
#
# Present genes :54
#
# Missing genes:0
#
#
# ## GSE46955
#
# Transcriptome analysis of blood monocytes from sepsis patients. Blood monocytes from gram-negative sepsis patients during sepsis (Sepsis) and following their recovery (Recovery/Basal) as well as healthy donor (control) were isolated. Thereafter, these cells were treated ex vivo with or without LPS for 3h and analysed for transcriptomic study.
#
# Sepsis + recovery from sepsis + healthy.
#
# Present genes :52
#
# Missing genes:2("HMGB1"  "FCGR1A")
